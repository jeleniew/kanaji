# %%
import os
from dotenv import load_dotenv

load_dotenv()

FOLDER_PATH = os.getenv("FOLDER_PATH")
files = [f"{FOLDER_PATH}_{i:02d}" for i in range(1, 51)]
OUTPUT_PATH = os.getenv("OUTPUT_PATH")

def jis_to_unicode(jis_code):
    # JIS X 0208
    b1 = (jis_code >> 8) & 0xFF
    b2 = jis_code & 0xFF

    byte_seq = bytes([0x1B, 0x24, 0x42, b1, b2, 0x1B, 0x28, 0x42])

    return byte_seq.decode('iso2022_jp')

def unicode_to_jis(char):
    # JIS X 0208
    byte_seq = char.encode('iso2022_jp')
    if len(byte_seq) < 6:
        raise ValueError("Character cannot be converted to JIS code")

    b1 = byte_seq[3]
    b2 = byte_seq[4]

    jis_code = (b1 << 8) | b2
    return jis_code

kanji = [
    # First Grade (80 kanji)
    '一', '二', '三', '四', '五',
    '六', '七', '八', '九', '十',
    '百', '千', '上', '下', '左',
    '右', '中', '大', '小', '月',
    '日', '年', '早', '木', '林',
    '山', '川', '土', '空', '田',
    '天', '生', '花', '草', '虫',
    '犬', '人', '名', '女', '男',
    '子', '目', '耳', '口', '手',
    '足', '見', '音', '力', '気',
    '円', '入', '出', '立', '休',
    '先', '夕', '本', '文', '字',
    '学', '校', '村', '町', '森',
    '正', '水', '火', '玉', '王',
    '石', '竹', '糸', '貝', '車',
    '金', '雨', '赤', '青', '白',
    # Second Grade (160 kanji)
    '数', '多', '少', '万', '半',
    '形', '太', '細', '広', '長',
    '点', '丸', '交', '光', '角',
    '計', '直', '線', '矢', '弱',
    '父', '強', '高', '同', '親',
    '母', '姉', '兄', '弟', '妹',
    '自', '友', '体', '毛', '頭',
    '顔', '首', '心', '時', '曜',
    '朝', '昼', '夜', '分', '週',
    '春', '夏', '秋', '冬', '今',
    '新', '古', '間', '方', '北',
    '南', '東', '西', '遠', '近',
    '前', '後', '内', '外', '場',
    '地', '国', '園', '谷', '野',
    '原', '里', '市', '京', '風',
    '雪', '雲', '池', '海', '岩',
    '星', '室', '戸', '家', '寺',
    '通', '門', '道', '話', '言',
    '答', '声', '聞', '語', '読',
    '書', '記', '紙', '画', '絵',
    '図', '工', '教', '晴', '思',
    '考', '知', '才', '理', '算',
    '作', '元', '食', '肉', '馬',
    '牛', '魚', '鳥', '羽', '鳴',
    '麦', '米', '茶', '色', '黄',
    '黒', '来', '行', '帰', '歩',
    '走', '止', '活', '店', '買',
    '売', '午', '汽', '弓', '回',
    '会', '組', '船', '明', '社',
    '切', '電', '毎', '合', '当',
    '台', '楽', '公', '引', '科',
    '歌', '刀', '番', '用', '何',
    # Third Grade (200 kanji)
    '丁', '世', '両', '主', '乗',
    '予', '事', '仕', '他', '代',
    '住', '使', '係', '倍', '全',
    '具', '写', '列', '助', '勉',
    '動', '勝', '化', '区', '医',
    '去', '反', '取', '受', '号',
    '向', '君', '味', '命', '和',
    '品', '員', '商', '問', '坂',
    '央', '始', '委', '守', '安',
    '定', '実', '客', '宮', '宿',
    '寒', '対', '局', '屋', '岸',
    '島', '州', '帳', '平', '幸',
    '度', '庫', '庭', '式', '役',
    '待', '急', '息', '悪', '悲',
    '想', '意', '感', '所', '打',
    '投', '拾', '持', '指', '放',
    '整', '旅', '族', '昔', '昭',
    '暑', '暗', '曲', '有', '服',
    '期', '板', '柱', '根', '植',
    '業', '様', '横', '橋', '次',
    '歯', '死', '氷', '決', '油',
    '波', '注', '泳', '洋', '流',
    '消', '深', '温', '港', '湖',
    '湯', '漢', '炭', '物', '球',
    '由', '申', '界', '畑', '病',
    '発', '登', '皮', '皿', '相',
    '県', '真', '着', '短', '研',
    '礼', '神', '祭', '福', '秒',
    '究', '章', '童', '笛', '第',
    '筆', '等', '箱', '級', '終',
    '緑', '練', '羊', '美', '習',
    '者', '育', '苦', '荷', '落',
    '葉', '薬', '血', '表', '詩',
    '調', '談', '豆', '負', '起',
    '路', '身', '転', '軽', '農',
    '返', '追', '送', '速', '進',
    '遊', '運', '部', '都', '配',
    '酒', '重', '鉄', '銀', '開',
    '院', '陽', '階', '集', '面',
    '題', '飲', '館', '駅', '鼻',
    # Fourth Grade (200 kanji)
    '不', '争', '付', '令', '以',
    '仲', '伝', '位', '低', '例',
    '便', '信', '倉', '候', '借',
    '停', '健', '側', '働', '億',
    '兆', '児', '共', '兵', '典',
    '冷', '初', '別', '利', '刷',
    '副', '功', '加', '努', '労',
    '勇', '包', '卒', '協', '単',
    '博', '印', '参', '史', '司',
    '各', '告', '周', '唱', '喜',
    '器', '囲', '固', '型', '堂',
    '塩', '士', '変', '夫', '失',
    '好', '季', '孫', '完', '官',
    '害', '察', '巣', '差', '希',
    '席', '帯', '底', '府', '康',
    '建', '径', '徒', '得', '必',
    '念', '愛', '成', '戦', '折',
    '挙', '改', '救', '敗', '散',
    '料', '旗', '昨', '景', '最',
    '望', '未', '末', '札', '材',
    '束', '松', '果', '栄', '案',
    '梅', '械', '極', '標', '機',
    '欠', '歴', '残', '殺', '毒',
    '氏', '民', '求', '治', '法',
    '泣', '浅', '浴', '清', '満',
    '漁', '灯', '無', '然', '焼',
    '照', '熱', '牧', '特', '産',
    '的', '省', '祝', '票', '種',
    '積', '競', '笑', '管', '節',
    '粉', '紀', '約', '結', '給',
    '続', '置', '老', '胃', '脈',
    '腸', '臣', '航', '良', '芸',
    '芽', '英', '菜', '街', '衣',
    '要', '覚', '観', '訓', '試',
    '説', '課', '議', '象', '貨',
    '貯', '費', '賞', '軍', '輪',
    '辞', '辺', '連', '達', '選',
    '郡', '量', '録', '鏡', '関',
    '陸', '隊', '静', '順', '願',
    '類', '飛', '飯', '養', '験',
    # Fifth Grade (185 kanji)
    '久', '仏', '仮', '件', '任',
    '似', '余', '価', '保', '修',
    '俵', '個', '備', '像', '再',
    '刊', '判', '制', '券', '則',
    '効', '務', '勢', '厚', '句',
    '可', '営', '因', '団', '圧',
    '在', '均', '基', '報', '境',
    '墓', '増', '夢', '妻', '婦',
    '容', '寄', '富', '導', '居',
    '属', '布', '師', '常', '幹',
    '序', '弁', '張', '往', '復',
    '徳', '志', '応', '快', '性',
    '恩', '情', '態', '慣', '承',
    '技', '招', '授', '採', '接',
    '提', '損', '支', '政', '故',
    '敵', '断', '旧', '易', '暴',
    '条', '枝', '査', '格', '桜',
    '検', '構', '武', '比', '永',
    '河', '液', '混', '減', '測',
    '準', '演', '潔', '災', '燃',
    '版', '犯', '状', '独', '率',
    '現', '留', '略', '益', '眼',
    '破', '確', '示', '祖', '禁',
    '移', '程', '税', '築', '精',
    '素', '経', '統', '絶', '綿',
    '総', '編', '績', '織', '罪',
    '群', '義', '耕', '職', '肥',
    '能', '興', '舌', '舎', '術',
    '衛', '製', '複', '規', '解',
    '設', '許', '証', '評', '講',
    '謝', '識', '護', '豊', '財',
    '貧', '責', '貸', '貿', '賀',
    '資', '賛', '質', '輸', '述',
    '迷', '退', '逆', '造', '過',
    '適', '酸', '鉱', '銅', '銭',
    '防', '限', '険', '際', '雑',
    '非', '預', '領', '額', '飼',
    # Sixth Grade (181)
    '並', '乱', '乳', '亡', '仁',
    '供', '俳', '値', '傷', '優',
    '党', '冊', '処', '刻', '割',
    '創', '劇', '勤', '危', '卵',
    '厳', '収', '后', '否', '吸',
    '呼', '善', '困', '垂', '城',
    '域', '奏', '奮', '姿', '存',
    '孝', '宅', '宇', '宗', '宙',
    '宝', '宣', '密', '寸', '専',
    '射', '将', '尊', '就', '尺',
    '届', '展', '層', '己', '巻',
    '幕', '干', '幼', '庁', '座',
    '延', '律', '従', '忘', '忠',
    '憲', '我', '批', '担', '拝',
    '拡', '捨', '探', '推', '揮',
    '操', '敬', '映', '晩', '暖',
    '暮', '朗', '机', '枚', '染',
    '株', '棒', '模', '権', '樹',
    '欲', '段', '沿', '泉', '洗',
    '派', '済', '源', '潮', '激',
    '灰', '熟', '片', '班', '異',
    '疑', '痛', '皇', '盛', '盟',
    '看', '砂', '磁', '私', '秘',
    '穀', '穴', '窓', '筋', '策',
    '簡', '糖', '系', '紅', '納',
    '純', '絹', '縦', '縮', '署',
    '翌', '聖', '肺', '背', '胸',
    '脳', '腹', '臓', '臨', '至',
    '若', '著', '蒸', '蔵', '蚕',
    '衆', '裁', '装', '裏', '補',
    '視', '覧', '討', '訪', '訳',
    '詞', '誌', '認', '誕', '誠',
    '誤', '論', '諸', '警', '貴',
    '賃', '遺', '郵', '郷', '針',
    '鋼', '閉', '閣', '降', '陛',
    '除', '障', '難', '革', '頂',
    '骨'
    # Junior High School part 1 (316 kanji)
    '握', '扱', '依', '威', '為',
    '偉', '違', '維', '緯', '壱',
    '芋', '陰', '隠', '影', '鋭',
    '越', '援', '煙', '鉛', '縁',
    '汚', '押', '奥', '憶', '菓',
    '暇', '箇', '雅', '介', '戒',
    '皆', '壊', '較', '獲', '刈',
    '甘', '汗', '乾', '勧', '歓',
    '監', '環', '鑑', '含', '奇',
    '祈', '鬼', '幾', '輝', '儀',
    '戯', '詰', '却', '脚', '及',
    '丘', '朽', '巨', '拠', '距',
    '御', '凶', '叫', '狂', '況',
    '狭', '恐', '響', '驚', '仰',
    '駆', '屈', '掘', '繰', '恵',
    '傾', '継', '迎', '撃', '肩',
    '兼', '剣', '軒', '圏', '堅',
    '遣', '玄', '枯', '誇', '鼓',
    '互', '抗', '攻', '更', '恒',
    '荒', '香', '項', '稿', '豪',
    '込', '婚', '鎖', '彩', '歳',
    '載', '剤', '咲', '惨', '旨',
    '伺', '刺', '脂', '紫', '雌',
    '執', '芝', '斜', '煮', '釈',
    '寂', '朱', '狩', '趣', '需',
    '舟', '秀', '襲', '柔', '獣',
    '瞬', '旬', '巡', '盾', '召',
    '床', '沼', '称', '紹', '詳',
    '丈', '畳', '殖', '飾', '触',
    '侵', '振', '浸', '寝', '慎',
    '震', '薪', '尽', '陣', '尋',
    '吹', '是', '井', '姓', '征',
    '跡', '占', '扇', '鮮', '訴',
    '僧', '燥', '騒', '贈', '即',
    '俗', '耐', '替', '沢', '拓',
    '濁', '脱', '丹', '淡', '嘆',
    '端', '弾', '恥', '致', '遅',
    '蓄', '沖', '跳', '徴', '澄',
    '沈', '珍', '抵', '堤', '摘',
    '滴', '添', '殿', '吐', '途',
    '渡', '奴', '怒', '到', '逃',
    '倒', '唐', '桃', '透', '盗',
    '塔', '稲', '踏', '闘', '胴',
    '峠', '突', '鈍', '曇', '弐',
    '悩', '濃', '杯', '輩', '拍',
    '泊', '迫', '薄', '爆', '髪',
    '抜', '罰', '般', '販', '搬',
    '範', '繁', '盤', '彼', '疲',
    '被', '避', '尾', '微', '匹',
    '描', '浜', '敏', '怖', '浮',
    '普', '腐', '敷', '膚', '賦',
    '舞', '幅', '払', '噴', '柄',
    '壁', '捕', '舗', '抱', '峰',
    '砲', '忙', '坊', '肪', '冒',
    '傍', '帽', '凡', '盆', '慢',
    '漫', '妙', '眠', '矛', '霧',
    '娘', '茂', '猛', '網', '黙',
    '紋', '躍', '雄', '与', '誉',
    '溶', '腰', '踊', '謡', '翼',
    '雷', '頼', '絡', '欄', '離',
    '粒', '慮', '療', '隣', '涙',
    '隷', '齢', '麗', '暦', '劣',
    '烈', '恋', '露', '郎', '惑',
    '腕',
    # Junior High School part 2 (285 kanji)
    '哀', '慰', '詠', '悦', '閲',
    '炎', '宴', '欧', '殴', '乙',
    '卸', '穏', '佳', '架', '華',
    '嫁', '餓', '怪', '悔', '塊',
    '慨', '該', '概', '郭', '隔',
    '穫', '岳', '掛', '滑', '肝',
    '冠', '勘', '貫', '喚', '換',
    '敢', '緩', '企', '岐', '忌',
    '軌', '既', '棋', '棄', '騎',
    '欺', '犠', '菊', '吉', '喫',
    '虐', '虚', '峡', '脅', '凝',
    '斤', '緊', '愚', '偶', '遇',
    '刑', '契', '啓', '掲', '携',
    '憩', '鶏', '鯨', '倹', '賢',
    '幻', '孤', '弧', '雇', '顧',
    '娯', '悟', '孔', '巧', '甲',
    '坑', '拘', '郊', '控', '慌',
    '硬', '絞', '綱', '酵', '克',
    '獄', '恨', '紺', '魂', '墾',
    '債', '催', '削', '搾', '錯',
    '撮', '擦', '暫', '祉', '施',
    '諮', '侍', '慈', '軸', '疾',
    '湿', '赦', '邪', '殊', '寿',
    '潤', '遵', '如', '徐', '匠',
    '昇', '掌', '晶', '焦', '衝',
    '鐘', '冗', '嬢', '錠', '譲',
    '嘱', '辱', '伸', '辛', '審',
    '炊', '粋', '衰', '酔', '遂',
    '穂', '随', '髄', '瀬', '牲',
    '婿', '請', '斥', '隻', '惜',
    '籍', '摂', '潜', '繕', '阻',
    '措', '粗', '礎', '双', '桑',
    '掃', '葬', '遭', '憎', '促',
    '賊', '怠', '胎', '袋', '逮',
    '滞', '滝', '択', '卓', '託',
    '諾', '奪', '胆', '鍛', '壇',
    '稚', '畜', '窒', '抽', '鋳',
    '駐', '彫', '超', '聴', '陳',
    '鎮', '墜', '帝', '訂', '締',
    '哲', '斗', '塗', '凍', '陶',
    '痘', '匿', '篤', '豚', '尿',
    '粘', '婆', '排', '陪', '縛',
    '伐', '帆', '伴', '畔', '藩',
    '蛮', '卑', '碑', '泌', '姫',
    '漂', '苗', '赴', '符', '封',
    '伏', '覆', '紛', '墳', '癖',
    '募', '慕', '簿', '芳', '邦',
    '奉', '胞', '倣', '崩', '飽',
    '縫', '乏', '妨', '房', '某',
    '膨', '謀', '墨', '没', '翻',
    '魔', '埋', '膜', '又', '魅',
    '滅', '免', '幽', '誘', '憂',
    '揚', '揺', '擁', '抑', '裸',
    '濫', '吏', '隆', '了', '猟',
    '陵', '糧', '厘', '励', '零',
    '霊', '裂', '廉', '錬', '炉',
    '浪', '廊', '楼', '漏', '湾',
    # Senior High School part 1 (333 kanji)
    '亜', '尉', '逸', '姻', '韻',
    '畝', '浦', '疫', '謁', '猿',
    '凹', '翁', '虞', '渦', '禍',
    '靴', '寡', '稼', '蚊', '拐',
    '懐', '劾', '涯', '垣', '核',
    '殻', '嚇', '潟', '括', '喝',
    '渇', '褐', '轄', '且', '缶',
    '陥', '患', '堪', '棺', '款',
    '閑', '寛', '憾', '還', '艦',
    '頑', '飢', '宜', '偽', '擬',
    '糾', '窮', '拒', '享', '挟',
    '恭', '矯', '暁', '菌', '琴',
    '謹', '襟', '吟', '隅', '勲',
    '薫', '茎', '渓', '蛍', '慶',
    '傑', '嫌', '献', '謙', '繭',
    '顕', '懸', '弦', '呉', '碁',
    '江', '肯', '侯', '洪', '貢',
    '溝', '衡', '購', '拷', '剛',
    '酷', '昆', '懇', '佐', '唆',
    '詐', '砕', '宰', '栽', '斎',
    '崎', '索', '酢', '桟', '傘',
    '肢', '嗣', '賜', '滋', '璽',
    '漆', '遮', '蛇', '酌', '爵',
    '珠', '儒', '囚', '臭', '愁',
    '酬', '醜', '汁', '充', '渋',
    '銃', '叔', '淑', '粛', '塾',
    '俊', '准', '殉', '循', '庶',
    '緒', '叙', '升', '抄', '肖',
    '尚', '宵', '症', '祥', '渉',
    '訟', '硝', '粧', '詔', '奨',
    '彰', '償', '礁', '浄', '剰',
    '縄', '壌', '醸', '津', '唇',
    '娠', '紳', '診', '刃', '迅',
    '甚', '帥', '睡', '枢', '崇',
    '据', '杉', '斉', '逝', '誓',
    '析', '拙', '窃', '仙', '栓',
    '旋', '践', '遷', '薦', '繊',
    '禅', '漸', '租', '疎', '塑',
    '壮', '荘', '捜', '挿', '曹',
    '喪', '槽', '霜', '藻', '妥',
    '堕', '惰', '駄', '泰', '濯',
    '但', '棚', '痴', '逐', '秩',
    '嫡', '衷', '弔', '挑', '眺',
    '釣', '懲', '勅', '朕', '塚',
    '漬', '坪', '呈', '廷', '邸',
    '亭', '貞', '逓', '偵', '艇',
    '泥', '迭', '徹', '撤', '悼',
    '搭', '棟', '筒', '謄', '騰',
    '洞', '督', '凸', '屯', '軟',
    '尼', '妊', '忍', '寧', '把',
    '覇', '廃', '培', '媒', '賠',
    '伯', '舶', '漠', '肌', '鉢',
    '閥', '煩', '頒', '妃', '披',
    '扉', '罷', '猫', '賓', '頻',
    '瓶', '扶', '附', '譜', '侮',
    '沸', '雰', '憤', '丙', '併',
    '塀', '幣', '弊', '偏', '遍',
    '泡', '俸', '褒', '剖', '紡',
    '朴', '僕', '撲', '堀', '奔',
    '麻', '摩', '磨', '抹', '岬',
    '銘', '妄', '盲', '耗', '厄',
    '愉', '諭', '癒', '唯', '悠',
    '猶', '裕', '融', '庸', '窯',
    '羅', '酪', '痢', '履', '柳',
    '竜', '硫', '虜', '涼', '僚',
    '寮', '倫', '累', '塁', '戻',
    '鈴', '賄', '枠',
     # Senior High School part 2 (196 kanji)
    '挨', '曖', '宛', '嵐', '畏',
    '萎', '椅', '彙', '茨', '咽',
    '淫', '唄', '鬱', '怨', '媛',
    '艶', '旺', '岡', '臆', '俺',
    '苛', '牙', '瓦', '楷', '潰',
    '諧', '崖', '蓋', '骸', '柿',
    '顎', '葛', '釜', '鎌', '韓',
    '玩', '伎', '亀', '毀', '畿',
    '臼', '嗅', '巾', '僅', '錦',
    '惧', '串', '窟', '熊', '詣',
    '憬', '稽', '隙', '桁', '拳',
    '鍵', '舷', '股', '虎', '錮',
    '勾', '梗', '喉', '乞', '傲',
    '駒', '頃', '痕', '沙', '挫',
    '采', '塞', '埼', '柵', '刹',
    '拶', '斬', '恣', '摯', '餌',
    '鹿', '叱', '嫉', '腫', '呪',
    '袖', '羞', '蹴', '憧', '拭',
    '尻', '芯', '腎', '須', '裾',
    '凄', '醒', '脊', '戚', '煎',
    '羨', '腺', '詮', '箋', '膳',
    '狙', '遡', '曽', '爽', '痩',
    '踪', '捉', '遜', '汰', '唾',
    '堆', '戴', '誰', '旦', '綻',
    '緻', '酎', '貼', '嘲', '捗',
    '椎', '爪', '鶴', '諦', '溺',
    '填', '妬', '賭', '藤', '瞳',
    '栃', '頓', '貪', '丼', '那',
    '奈', '梨', '謎', '鍋', '匂',
    '虹', '捻', '罵', '剥', '箸',
    '氾', '汎', '阪', '斑', '眉',
    '膝', '肘', '阜', '訃', '蔽',
    '餅', '璧', '蔑', '哺', '蜂',
    '貌', '頬', '睦', '勃', '昧',
    '枕', '蜜', '冥', '麺', '冶',
    '弥', '闇', '喩', '湧', '妖',
    '瘍', '沃', '拉', '辣', '藍',
    '璃', '慄', '侶', '瞭', '瑠',
    '呂', '賂', '弄', '籠', '麓',
    '脇',
]

selected_characters = kanji[0:1006]

selected_jis = []

for char in selected_characters:
    jis_code = unicode_to_jis(char)
    selected_jis.append(jis_code)

# %%
import tensorflow as tf
from dataclasses import dataclass
import numpy as np
import cv2


@dataclass
class Record:
    """One record from a file ETL9G."""
    jis_code: int
    img: np.ndarray


def swap_white_and_black(img: np.ndarray) -> np.ndarray:
    """
    Swaps white and black pixels in the image.
    """
    return 15 - img


def clean_image_background(img: np.ndarray) -> np.ndarray:
    """
    Removes unwanted objects that touch the edges of the image.
    This helps eliminate neighboring fragments that result from scanning multiple samples from one sheet.
    Uses bfs to find connected components touching the edges and removes them.
    """
    # TODO: remove small objects inside the image
    # TOOD: check y and x order
    h, w = img.shape
    visited = np.zeros((h, w), dtype=bool)

    def bfs(start_x: int, start_y: int):
        queue = [(start_x, start_y)]
        while queue:
            x, y = queue.pop(0)
            if visited[x, y]:
                continue
            visited[x, y] = True
            if img[x, y] > 0:
                img[x, y] = 0
                for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
                    nx, ny = x + dx, y + dy
                    if 0 <= nx < h and 0 <= ny < w and not visited[nx, ny]:
                        queue.append((nx, ny))

    for i in range(h):
        if not visited[i, 0]:
            bfs(i, 0)
        if not visited[i, w - 1]:
            bfs(i, w - 1)
    for i in range(w):
        if not visited[0, i]:
            bfs(0, i)
        if not visited[h - 1, i]:
            bfs(h - 1, i)

    return img


def cut_center_and_scale(img: np.ndarray, add_margin: bool = False) -> np.ndarray:
    """
    Cuts the center of the image and scales it to a fixed size.
    """
    mask = img > 1
    coords = np.argwhere(mask)

    if coords.size == 0:
        return img
    
    # TODO: check if +1 is needed
    y0, x0 = coords.min(axis=0)
    y1, x1 = coords.max(axis=0) + 1  # slices are exclusive at the top and bottom
    cropped_img = img[y0:y1, x0:x1]
    ch, cw = cropped_img.shape
    if add_margin:
        cropped_img = np.pad(cropped_img, pad_width=2, mode='constant', constant_values=0)

    scale = min(127 / ch, 128 / cw)
    new_h = int(ch * scale)
    new_w = int(cw * scale)

    scaled_img = tf.image.resize(
        cropped_img[..., np.newaxis],
        (new_h, new_w), method='bilinear'
    ).numpy()
    
    canvas = np.zeros((127, 128, 1), dtype=scaled_img.dtype)

    y_offset = (127 - new_h) // 2
    x_offset = (128 - new_w) // 2
    canvas[y_offset:y_offset+new_h, x_offset:x_offset+new_w, :] = scaled_img

    return canvas.astype(np.uint8).squeeze()


def convert_to_binary_image(img: np.ndarray, threshold = 3) -> np.ndarray:
    """
    Converts grayscale image to binary (black and white) image using thresholding.
    """
    binary_img = np.where(img > threshold, 15, 0).astype(np.uint8)
    return binary_img


def smooth_edges(img: np.ndarray, kernel_size: int = 7) -> np.ndarray:
    """
    Smooths the edges of the image using Gaussian blur.
    """
    img = cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)
    return img


def thin_lines(img: np.ndarray, kernel_size: int = 2) -> np.ndarray:
    """
    Thins the lines in the image using morphological operations.
    """
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    img = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
    return img
# Out:
# 2026-01-09 10:35:45.175356: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-09 10:35:45.718203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-09 10:35:47.415996: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import queue
import threading
import time
from typing import BinaryIO, Optional
from collections.abc import Generator
from pyparsing import Iterator, deque
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
import struct
import numpy as np
import matplotlib.pyplot as plt


os.environ["CUDA_VISIBLE_DEVICES"] = "-1"


early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)


def read_etl9g_records_from_file(f: BinaryIO) -> Optional[Record]:
    """
    Reads one record from a file ETL9G.
    Returns: (jis_code, img)
    """
    s = f.read(8199)
    if not s:
        return None
    r = struct.unpack('>HH8sIBBBBHHHHBB34s8128s7x', s)
    jis_code = r[1]
    img_bytes = r[15]
    
    arr = np.frombuffer(img_bytes, dtype = np.uint8)
    high = arr >> 4
    low = arr & 0x0F
    pixels = np.empty(arr.size * 2, dtype = np.uint8)
    pixels[0::2] = high
    pixels[1::2] = low
    img = pixels.reshape(127, 128)

    return Record(jis_code, img)


def simple_preprocess(img: np.ndarray) -> np.ndarray:
    """
    Simple preprocessing steps.
    """
    img = clean_image_background(img)
    img = cut_center_and_scale(img)
    img = convert_to_binary_image(img)
    img = swap_white_and_black(img)
    return img


def create_cnn(with_augmentation=True):
    model = tf.keras.Sequential()
    model.add(layers.Input(shape=(127, 128, 1)))

    if with_augmentation:
        model.add(tf.keras.Sequential([
            layers.RandomRotation(0.1),
            layers.RandomZoom(height_factor=(-0.1, 0.0), width_factor=(-0.1, 0.0)),
            # layers.RandomTranslation(0.1, 0.1),   # not needed because images are centered
            # layers.RandomFlip("horizontal")       # shouldn't be used for writing
        ]))

    model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D())
    model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D())
    model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D())
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(len(selected_jis), activation='softmax'))

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model


def threaded_buffered_generator(buffer_size: int) -> Generator[tuple[np.ndarray, int], None, None]:
    """
    Generator z buforem i osobnym wątkiem do wypełniania bufora.
    """
    data_queue = queue.Queue(maxsize=buffer_size)
    stop_event = threading.Event()
    
    def producer():
        """Thread producing data."""
        records_produced = 0
        for file in files:
            if stop_event.is_set():
                break
                
            with open(file, 'rb') as f:
                while True:
                    if stop_event.is_set():
                        break
                        
                    record = read_etl9g_records_from_file(f)
                    if record is None:
                        break
                    
                    if record.jis_code in selected_jis:
                        img = simple_preprocess(record.img)
                        img_with_channel = np.expand_dims(img, axis=-1)
                        label = selected_jis.index(record.jis_code)
                        
                        data_queue.put((img_with_channel, label))
                        records_produced += 1
        
        # End of data signal
        data_queue.put(None)
        print(f"Producer finished: {records_produced} records produced")
    
    # Start producer thread
    producer_thread = threading.Thread(target=producer)
    producer_thread.daemon = True
    producer_thread.start()
    
    # Consumer
    total_consumed = 0
    
    try:
        while True:
            item = data_queue.get()
            
            if item is None:
                break
                
            total_consumed += 1
            
            yield item
            
    finally:
        stop_event.set()
        producer_thread.join(timeout=1)
        print(f"\nGenerator finished: {total_consumed} total records")


def split_data(dataset: tf.data.Dataset, train_size: int, validation_size: int) -> tuple[tf.data.Dataset, tf.data.Dataset]:
    """
    Splits the data into training, validation and test sets.
    """

    train_dataset = dataset.take(train_size)
    val_dataset = dataset.skip(train_size).take(validation_size)

    return train_dataset, val_dataset


def create_dataset_from_generator(generator_func, batch_size: int, buffer_size: int = 2000) -> tf.data.Dataset:
    """
    Create dataset from any generator.
    """
    dataset = tf.data.Dataset.from_generator(
        generator_func,
        output_signature=(
            tf.TensorSpec(shape=(127, 128, 1), dtype=tf.float32),
            tf.TensorSpec(shape=(), dtype=tf.int32),
        )
    )
    
    dataset = dataset.shuffle(buffer_size=min(buffer_size, 2000))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    
    return dataset


def save_model(model: tf.keras.Model, path: str):
    """
    Saves the model to the specified path.
    """
    model.export(path)
    converter = tf.lite.TFLiteConverter.from_saved_model(path)
    tflite_model = converter.convert()
    with open(f"{path}.tflite", "wb") as f:
        f.write(tflite_model)

if __name__ == "__main__":
    total_records = len(selected_jis) * 200
    train_size = int(total_records * 0.7)
    validation_size = int(total_records * 0.3)
    batch_size = 32


    def threaded_gen():
        for img, label in threaded_buffered_generator(buffer_size=100):
            yield img, label
    
    full_dataset = create_dataset_from_generator(threaded_gen, batch_size)

    model = create_cnn(with_augmentation=True)

    train_dataset, val_dataset = split_data(full_dataset, train_size, validation_size)

    train_dataset = train_dataset.repeat()
    val_dataset = val_dataset.repeat()
    
    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        steps_per_epoch=train_size // batch_size,
        validation_steps=validation_size // batch_size,
        epochs=50,
        callbacks=[early_stop]
    )
    # plt.plot(history.history['val_loss'])

    model_no_augmentation = create_cnn(with_augmentation=False)
    model_no_augmentation.set_weights(model.get_weights())
    save_model(model_no_augmentation, f"{OUTPUT_PATH}/cnn_etl9g_{len(selected_jis)}s_50e_nomargin_smooth_simple")
# Out:
# 2026-01-09 10:35:48.637937: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-01-09 10:35:48.637988: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2026-01-09 10:35:48.637995: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2026-01-09 10:35:48.638000: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2026-01-09 10:35:48.638005: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: wikusia-Nitro-AN515-57
# 2026-01-09 10:35:48.638008: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: wikusia-Nitro-AN515-57
# 2026-01-09 10:35:48.638175: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.95.5
# 2026-01-09 10:35:48.638226: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.95.5
# 2026-01-09 10:35:48.638229: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.95.5
# Epoch 1/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.0103 - loss: 6.6426Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 884s 200ms/step - accuracy: 0.0388 - loss: 5.9674
# Epoch 2/50
#    1/4401 ━━━━━━━━━━━━━━━━━━━━ 11:58 163ms/step - accuracy: 0.1250 - loss: 4.2396
# 2026-01-09 10:50:33.340212: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /home/wikusia/Desktop/modele/tf/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# /home/wikusia/Desktop/modele/tf/lib/python3.10/site-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 1815/4401 ━━━━━━━━━━━━━━━━━━━━ 6:24 149ms/step - accuracy: 0.1645 - loss: 4.3089Producer finished: 201200 records produced
# 1819/4401 ━━━━━━━━━━━━━━━━━━━━ 6:23 149ms/step - accuracy: 0.1645 - loss: 4.3084
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.2169 - loss: 3.9166Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 885s 201ms/step - accuracy: 0.3028 - loss: 3.3146
# Epoch 3/50
#    1/4401 ━━━━━━━━━━━━━━━━━━━━ 11:39 159ms/step - accuracy: 0.5000 - loss: 2.1728
# 2026-01-09 11:05:18.400243: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 3701/4401 ━━━━━━━━━━━━━━━━━━━━ 1:45 151ms/step - accuracy: 0.4544 - loss: 2.4461Producer finished: 201200 records produced
# 3705/4401 ━━━━━━━━━━━━━━━━━━━━ 1:44 151ms/step - accuracy: 0.4544 - loss: 2.4461
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4565 - loss: 2.4369Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 887s 202ms/step - accuracy: 0.4767 - loss: 2.3355
# Epoch 4/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5859 - loss: 1.7300Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 887s 202ms/step - accuracy: 0.5787 - loss: 1.7985
# Epoch 5/50
#    1/4401 ━━━━━━━━━━━━━━━━━━━━ 11:05 151ms/step - accuracy: 0.5000 - loss: 3.0822
# 2026-01-09 11:34:52.953062: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 1185/4401 ━━━━━━━━━━━━━━━━━━━━ 7:49 146ms/step - accuracy: 0.5461 - loss: 2.0322Producer finished: 201200 records produced
# 1189/4401 ━━━━━━━━━━━━━━━━━━━━ 7:48 146ms/step - accuracy: 0.5462 - loss: 2.0317
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5972 - loss: 1.7313Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 879s 200ms/step - accuracy: 0.6283 - loss: 1.5587
# Epoch 6/50
# 3068/4401 ━━━━━━━━━━━━━━━━━━━━ 3:19 150ms/step - accuracy: 0.6292 - loss: 1.5730Producer finished: 201200 records produced
# 3072/4401 ━━━━━━━━━━━━━━━━━━━━ 3:18 150ms/step - accuracy: 0.6292 - loss: 1.5731
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6288 - loss: 1.5740Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 882s 200ms/step - accuracy: 0.6400 - loss: 1.5103
# Epoch 7/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6668 - loss: 1.3903Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 881s 200ms/step - accuracy: 0.6385 - loss: 1.5529
# Epoch 8/50
#  546/4401 ━━━━━━━━━━━━━━━━━━━━ 9:19 145ms/step - accuracy: 0.5713 - loss: 1.8917Producer finished: 201200 records produced
#  550/4401 ━━━━━━━━━━━━━━━━━━━━ 9:19 145ms/step - accuracy: 0.5714 - loss: 1.8911
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6567 - loss: 1.4330Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 873s 198ms/step - accuracy: 0.6796 - loss: 1.3161
# Epoch 9/50
#    1/4401 ━━━━━━━━━━━━━━━━━━━━ 10:50 148ms/step - accuracy: 0.6875 - loss: 1.3108
# 2026-01-09 12:33:28.173169: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2417/4401 ━━━━━━━━━━━━━━━━━━━━ 4:48 146ms/step - accuracy: 0.6517 - loss: 1.4820Producer finished: 201200 records produced
# 2421/4401 ━━━━━━━━━━━━━━━━━━━━ 4:48 146ms/step - accuracy: 0.6517 - loss: 1.4821
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6595 - loss: 1.4435Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 864s 196ms/step - accuracy: 0.6819 - loss: 1.3303
# Epoch 10/50
# 4272/4401 ━━━━━━━━━━━━━━━━━━━━ 18s 147ms/step - accuracy: 0.7050 - loss: 1.1929Producer finished: 201200 records produced
# 4276/4401 ━━━━━━━━━━━━━━━━━━━━ 18s 147ms/step - accuracy: 0.7050 - loss: 1.1930
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7045 - loss: 1.1954Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 864s 196ms/step - accuracy: 0.6896 - loss: 1.2762
# Epoch 11/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7502 - loss: 0.9777Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 863s 196ms/step - accuracy: 0.7259 - loss: 1.1051
# Epoch 12/50
# 1758/4401 ━━━━━━━━━━━━━━━━━━━━ 6:23 145ms/step - accuracy: 0.6831 - loss: 1.3267Producer finished: 201200 records produced
# 1762/4401 ━━━━━━━━━━━━━━━━━━━━ 6:22 145ms/step - accuracy: 0.6831 - loss: 1.3267
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6899 - loss: 1.2952Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 867s 197ms/step - accuracy: 0.7065 - loss: 1.2136
# Epoch 13/50
# 3645/4401 ━━━━━━━━━━━━━━━━━━━━ 1:51 148ms/step - accuracy: 0.7304 - loss: 1.1066Producer finished: 201200 records produced
# 3649/4401 ━━━━━━━━━━━━━━━━━━━━ 1:51 148ms/step - accuracy: 0.7304 - loss: 1.1067
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7270 - loss: 1.1221Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 868s 197ms/step - accuracy: 0.7165 - loss: 1.1676
# Epoch 14/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7557 - loss: 0.9718Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 867s 197ms/step - accuracy: 0.7330 - loss: 1.0880
# Epoch 15/50
# 1131/4401 ━━━━━━━━━━━━━━━━━━━━ 7:52 144ms/step - accuracy: 0.6784 - loss: 1.3482Producer finished: 201200 records produced
# 1135/4401 ━━━━━━━━━━━━━━━━━━━━ 7:51 144ms/step - accuracy: 0.6784 - loss: 1.3478
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7230 - loss: 1.1278Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 870s 198ms/step - accuracy: 0.7469 - loss: 1.0185
# Epoch 16/50
# 3018/4401 ━━━━━━━━━━━━━━━━━━━━ 3:24 148ms/step - accuracy: 0.7224 - loss: 1.1426Producer finished: 201200 records produced
# 3022/4401 ━━━━━━━━━━━━━━━━━━━━ 3:23 148ms/step - accuracy: 0.7223 - loss: 1.1427
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7187 - loss: 1.1588Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 870s 198ms/step - accuracy: 0.7194 - loss: 1.1502
# Epoch 17/50
#    1/4401 ━━━━━━━━━━━━━━━━━━━━ 11:05 151ms/step - accuracy: 0.7500 - loss: 0.7716
# 2026-01-09 14:29:00.739214: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7467 - loss: 1.0372Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 865s 197ms/step - accuracy: 0.7363 - loss: 1.0853
# Epoch 18/50
#  504/4401 ━━━━━━━━━━━━━━━━━━━━ 9:19 144ms/step - accuracy: 0.6950 - loss: 1.2860Producer finished: 201200 records produced
#  508/4401 ━━━━━━━━━━━━━━━━━━━━ 9:19 144ms/step - accuracy: 0.6950 - loss: 1.2859
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7498 - loss: 1.0076Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 865s 197ms/step - accuracy: 0.7570 - loss: 0.9808
# Epoch 19/50
# 2391/4401 ━━━━━━━━━━━━━━━━━━━━ 4:54 147ms/step - accuracy: 0.6905 - loss: 1.3143Producer finished: 201200 records produced
# 2395/4401 ━━━━━━━━━━━━━━━━━━━━ 4:54 147ms/step - accuracy: 0.6905 - loss: 1.3141
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7102 - loss: 1.2176Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 869s 198ms/step - accuracy: 0.7449 - loss: 1.0500
# Epoch 20/50
# 4278/4401 ━━━━━━━━━━━━━━━━━━━━ 18s 149ms/step - accuracy: 0.7564 - loss: 0.9840Producer finished: 201200 records produced
# 4282/4401 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - accuracy: 0.7564 - loss: 0.9841
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7557 - loss: 0.9870Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 872s 198ms/step - accuracy: 0.7336 - loss: 1.0915
# Epoch 21/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7887 - loss: 0.8347Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 854s 194ms/step - accuracy: 0.7687 - loss: 0.9305
# Epoch 22/50
# 1764/4401 ━━━━━━━━━━━━━━━━━━━━ 6:18 143ms/step - accuracy: 0.7258 - loss: 1.1342Producer finished: 201200 records produced
# 1768/4401 ━━━━━━━━━━━━━━━━━━━━ 6:17 143ms/step - accuracy: 0.7258 - loss: 1.1341
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7416 - loss: 1.0555Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 864s 196ms/step - accuracy: 0.7578 - loss: 0.9850
# Epoch 23/50
# 3651/4401 ━━━━━━━━━━━━━━━━━━━━ 1:50 147ms/step - accuracy: 0.7518 - loss: 1.0453Producer finished: 201200 records produced
# 3655/4401 ━━━━━━━━━━━━━━━━━━━━ 1:49 147ms/step - accuracy: 0.7518 - loss: 1.0454
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7490 - loss: 1.0576Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 856s 195ms/step - accuracy: 0.7419 - loss: 1.0850
# Epoch 24/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7774 - loss: 0.8912Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 851s 193ms/step - accuracy: 0.7523 - loss: 1.0183
# Epoch 25/50
# 1137/4401 ━━━━━━━━━━━━━━━━━━━━ 7:41 141ms/step - accuracy: 0.7051 - loss: 1.2308Producer finished: 201200 records produced
# 1141/4401 ━━━━━━━━━━━━━━━━━━━━ 7:40 141ms/step - accuracy: 0.7052 - loss: 1.2303
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7417 - loss: 1.0620Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 834s 190ms/step - accuracy: 0.7342 - loss: 1.1152
# Epoch 26/50
# 3024/4401 ━━━━━━━━━━━━━━━━━━━━ 3:03 133ms/step - accuracy: 0.7057 - loss: 1.2447Producer finished: 201200 records produced
# 3028/4401 ━━━━━━━━━━━━━━━━━━━━ 3:02 133ms/step - accuracy: 0.7057 - loss: 1.2447
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7074 - loss: 1.2351Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 775s 176ms/step - accuracy: 0.7264 - loss: 1.1408
# Epoch 27/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7548 - loss: 1.0152Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 753s 171ms/step - accuracy: 0.7459 - loss: 1.0570
# Epoch 28/50
#  510/4401 ━━━━━━━━━━━━━━━━━━━━ 8:04 124ms/step - accuracy: 0.7055 - loss: 1.1993Producer finished: 201200 records produced
#  514/4401 ━━━━━━━━━━━━━━━━━━━━ 8:03 124ms/step - accuracy: 0.7055 - loss: 1.1991
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7659 - loss: 0.9401Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 751s 171ms/step - accuracy: 0.7774 - loss: 0.8930
# Epoch 29/50
# 2397/4401 ━━━━━━━━━━━━━━━━━━━━ 4:13 126ms/step - accuracy: 0.7326 - loss: 1.1035Producer finished: 201200 records produced
# 2401/4401 ━━━━━━━━━━━━━━━━━━━━ 4:12 126ms/step - accuracy: 0.7326 - loss: 1.1035
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7429 - loss: 1.0577Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 751s 171ms/step - accuracy: 0.7635 - loss: 0.9659
# Epoch 30/50
# 4284/4401 ━━━━━━━━━━━━━━━━━━━━ 15s 132ms/step - accuracy: 0.7643 - loss: 0.9812Producer finished: 201200 records produced
# 4288/4401 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.7643 - loss: 0.9812
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7639 - loss: 0.9824Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 790s 179ms/step - accuracy: 0.7514 - loss: 1.0263
# Epoch 31/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7851 - loss: 0.8694Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 822s 187ms/step - accuracy: 0.7672 - loss: 0.9584
# Epoch 32/50
# 1770/4401 ━━━━━━━━━━━━━━━━━━━━ 6:05 139ms/step - accuracy: 0.7356 - loss: 1.1095Producer finished: 201200 records produced
# 1774/4401 ━━━━━━━━━━━━━━━━━━━━ 6:04 139ms/step - accuracy: 0.7356 - loss: 1.1094
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7417 - loss: 1.0738Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 857s 195ms/step - accuracy: 0.7420 - loss: 1.0660
# Epoch 33/50
#    1/4401 ━━━━━━━━━━━━━━━━━━━━ 13:32 185ms/step - accuracy: 0.8125 - loss: 0.5556
# 2026-01-09 18:09:29.811367: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 3657/4401 ━━━━━━━━━━━━━━━━━━━━ 1:52 151ms/step - accuracy: 0.7317 - loss: 1.1109Producer finished: 201200 records produced
# 3661/4401 ━━━━━━━━━━━━━━━━━━━━ 1:51 151ms/step - accuracy: 0.7317 - loss: 1.1110
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7308 - loss: 1.1163Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 876s 199ms/step - accuracy: 0.7331 - loss: 1.1097
# Epoch 34/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7767 - loss: 0.9005Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 873s 198ms/step - accuracy: 0.7602 - loss: 0.9856
# Epoch 35/50
# 1143/4401 ━━━━━━━━━━━━━━━━━━━━ 7:52 145ms/step - accuracy: 0.6886 - loss: 1.3453Producer finished: 201200 records produced
# 1147/4401 ━━━━━━━━━━━━━━━━━━━━ 7:51 145ms/step - accuracy: 0.6887 - loss: 1.3447
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7421 - loss: 1.0732Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 861s 196ms/step - accuracy: 0.7706 - loss: 0.9337
# Epoch 36/50
# 3030/4401 ━━━━━━━━━━━━━━━━━━━━ 3:19 145ms/step - accuracy: 0.7490 - loss: 1.0456Producer finished: 201200 records produced
# 3034/4401 ━━━━━━━━━━━━━━━━━━━━ 3:18 145ms/step - accuracy: 0.7490 - loss: 1.0457
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7497 - loss: 1.0422Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 851s 193ms/step - accuracy: 0.7623 - loss: 0.9798
# Epoch 37/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7649 - loss: 0.9817Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 856s 195ms/step - accuracy: 0.7481 - loss: 1.0512
# Epoch 38/50
#  516/4401 ━━━━━━━━━━━━━━━━━━━━ 9:09 141ms/step - accuracy: 0.7057 - loss: 1.2109Producer finished: 201200 records produced
#  520/4401 ━━━━━━━━━━━━━━━━━━━━ 9:08 141ms/step - accuracy: 0.7058 - loss: 1.2108
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7602 - loss: 0.9700Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 850s 193ms/step - accuracy: 0.7696 - loss: 0.9385
# Epoch 39/50
# 2403/4401 ━━━━━━━━━━━━━━━━━━━━ 4:49 145ms/step - accuracy: 0.7371 - loss: 1.1165Producer finished: 201200 records produced
# 2407/4401 ━━━━━━━━━━━━━━━━━━━━ 4:49 145ms/step - accuracy: 0.7371 - loss: 1.1165
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7462 - loss: 1.0650Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 863s 196ms/step - accuracy: 0.7640 - loss: 0.9746
# Epoch 40/50
# 4290/4401 ━━━━━━━━━━━━━━━━━━━━ 16s 149ms/step - accuracy: 0.7751 - loss: 0.9192Producer finished: 201200 records produced
# 4294/4401 ━━━━━━━━━━━━━━━━━━━━ 15s 149ms/step - accuracy: 0.7751 - loss: 0.9192
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7746 - loss: 0.9213Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 874s 199ms/step - accuracy: 0.7577 - loss: 1.0001
# Epoch 41/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8024 - loss: 0.7882Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 877s 199ms/step - accuracy: 0.7835 - loss: 0.8839
# Epoch 42/50
# 1776/4401 ━━━━━━━━━━━━━━━━━━━━ 6:39 152ms/step - accuracy: 0.7457 - loss: 1.0706Producer finished: 201200 records produced
# 1780/4401 ━━━━━━━━━━━━━━━━━━━━ 6:39 152ms/step - accuracy: 0.7457 - loss: 1.0706
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7576 - loss: 1.0068Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 874s 199ms/step - accuracy: 0.7753 - loss: 0.9191
# Epoch 43/50
# 3663/4401 ━━━━━━━━━━━━━━━━━━━━ 1:48 147ms/step - accuracy: 0.7742 - loss: 0.9304Producer finished: 201200 records produced
# 3667/4401 ━━━━━━━━━━━━━━━━━━━━ 1:47 147ms/step - accuracy: 0.7742 - loss: 0.9306
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7717 - loss: 0.9421Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 849s 193ms/step - accuracy: 0.7644 - loss: 0.9746
# Epoch 44/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7881 - loss: 0.8721Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 875s 199ms/step - accuracy: 0.7561 - loss: 1.0369
# Epoch 45/50
# 1149/4401 ━━━━━━━━━━━━━━━━━━━━ 8:13 152ms/step - accuracy: 0.7038 - loss: 1.2837Producer finished: 201200 records produced
# 1153/4401 ━━━━━━━━━━━━━━━━━━━━ 8:13 152ms/step - accuracy: 0.7039 - loss: 1.2830
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7441 - loss: 1.0695Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 876s 199ms/step - accuracy: 0.7665 - loss: 0.9590
# Epoch 46/50
# 3036/4401 ━━━━━━━━━━━━━━━━━━━━ 3:28 153ms/step - accuracy: 0.7629 - loss: 0.9846Producer finished: 201200 records produced
# 3040/4401 ━━━━━━━━━━━━━━━━━━━━ 3:27 153ms/step - accuracy: 0.7629 - loss: 0.9847
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7626 - loss: 0.9859Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 894s 203ms/step - accuracy: 0.7717 - loss: 0.9415
# Epoch 47/50
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7815 - loss: 0.9061Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 876s 199ms/step - accuracy: 0.7709 - loss: 0.9480
# Epoch 48/50
#  522/4401 ━━━━━━━━━━━━━━━━━━━━ 8:51 137ms/step - accuracy: 0.7327 - loss: 1.1164Producer finished: 201200 records produced
#  526/4401 ━━━━━━━━━━━━━━━━━━━━ 8:50 137ms/step - accuracy: 0.7327 - loss: 1.1163
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7352 - loss: 1.2004Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 872s 198ms/step - accuracy: 0.6969 - loss: 1.4362
# Epoch 49/50
# 2409/4401 ━━━━━━━━━━━━━━━━━━━━ 4:50 146ms/step - accuracy: 0.6894 - loss: 1.3380Producer finished: 201200 records produced
# 2413/4401 ━━━━━━━━━━━━━━━━━━━━ 4:49 146ms/step - accuracy: 0.6894 - loss: 1.3379
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7035 - loss: 1.2658Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 886s 201ms/step - accuracy: 0.7308 - loss: 1.1343
# Epoch 50/50
# 4296/4401 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - accuracy: 0.7562 - loss: 1.0292Producer finished: 201200 records produced
# 4300/4401 ━━━━━━━━━━━━━━━━━━━━ 15s 156ms/step - accuracy: 0.7562 - loss: 1.0293
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7557 - loss: 1.0311Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 912s 207ms/step - accuracy: 0.7380 - loss: 1.1099
#
# Generator finished: 3215 total records
# INFO:tensorflow:Assets written to: ./models/cnn_etl9g_1006s_50e_nomargin_smooth_simple/assets
# INFO:tensorflow:Assets written to: ./models/cnn_etl9g_1006s_50e_nomargin_smooth_simple/assets
# Saved artifact at './models/cnn_etl9g_1006s_50e_nomargin_smooth_simple'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 127, 128, 1), dtype=tf.float32, name='keras_tensor_70')
# Output Type:
#   TensorSpec(shape=(None, 1006), dtype=tf.float32, name=None)
# Captures:
#   134465429214256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429209680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429224992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429214608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429383728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429381792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134466102263504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429608352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429613808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134465429614512: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1767994268.861746    7816 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1767994268.862256    7816 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2026-01-09 22:31:08.870581: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: ./models/cnn_etl9g_1006s_50e_nomargin_smooth_simple
# 2026-01-09 22:31:08.871654: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2026-01-09 22:31:08.871660: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: ./models/cnn_etl9g_1006s_50e_nomargin_smooth_simple
# I0000 00:00:1767994268.879846    7816 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# 2026-01-09 22:31:08.880919: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2026-01-09 22:31:08.939673: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: ./models/cnn_etl9g_1006s_50e_nomargin_smooth_simple
# 2026-01-09 22:31:08.947616: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 77032 microseconds.
# 2026-01-09 22:31:09.001533: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
model.save("./models/cnn_etl9g_50e.keras")

# %%
import tensorflow as tf

# Read the saved model
model = tf.keras.models.load_model("./models/cnn_etl9g_50e.keras")

# Callback for saving checkpoints every epoch (optional)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "checkpoints/epoch_{epoch:03d}.keras",  # saves the full model every epoch
    save_weights_only=False,
    save_freq='epoch'
)

# Resume training
model.fit(
    train_dataset,
    validation_data=val_dataset,       # if you have validation data
    steps_per_epoch=train_size // batch_size,
    epochs=70,                          # target number of epochs
    initial_epoch=50,                   # start from epoch 50
    callbacks=[checkpoint]              # checkpoint saving
)
# Out:
# Epoch 51/70
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7963 - loss: 0.8276Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# /home/wikusia/Desktop/modele/tf/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 905s 205ms/step - accuracy: 0.7658 - loss: 0.9865
# Epoch 52/70
# 1815/4401 ━━━━━━━━━━━━━━━━━━━━ 6:58 162ms/step - accuracy: 0.7089 - loss: 1.2473Producer finished: 201200 records produced
# 1819/4401 ━━━━━━━━━━━━━━━━━━━━ 6:57 162ms/step - accuracy: 0.7089 - loss: 1.2472
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7306 - loss: 1.1326Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 938s 213ms/step - accuracy: 0.7587 - loss: 0.9957
# Epoch 53/70
# 3701/4401 ━━━━━━━━━━━━━━━━━━━━ 1:49 157ms/step - accuracy: 0.7003 - loss: 1.4436Producer finished: 201200 records produced
# 3705/4401 ━━━━━━━━━━━━━━━━━━━━ 1:49 157ms/step - accuracy: 0.7002 - loss: 1.4446
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6790 - loss: 1.5727Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 915s 208ms/step - accuracy: 0.5752 - loss: 2.1829
# Epoch 54/70
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6853 - loss: 1.3477Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 899s 204ms/step - accuracy: 0.6791 - loss: 1.3873
# Epoch 55/70
# 1185/4401 ━━━━━━━━━━━━━━━━━━━━ 8:11 153ms/step - accuracy: 0.6536 - loss: 1.5188Producer finished: 201200 records produced
# 1189/4401 ━━━━━━━━━━━━━━━━━━━━ 8:10 153ms/step - accuracy: 0.6537 - loss: 1.5184
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6967 - loss: 1.2944Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 928s 211ms/step - accuracy: 0.7225 - loss: 1.1660
# Epoch 56/70
# 3068/4401 ━━━━━━━━━━━━━━━━━━━━ 3:32 159ms/step - accuracy: 0.7094 - loss: 1.2502Producer finished: 201200 records produced
# 3072/4401 ━━━━━━━━━━━━━━━━━━━━ 3:31 159ms/step - accuracy: 0.7094 - loss: 1.2503
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7091 - loss: 1.2491Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 945s 215ms/step - accuracy: 0.7184 - loss: 1.1923
# Epoch 57/70
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7341 - loss: 1.1333Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 903s 205ms/step - accuracy: 0.7223 - loss: 1.1775
# Epoch 58/70
#  546/4401 ━━━━━━━━━━━━━━━━━━━━ 8:52 138ms/step - accuracy: 0.6843 - loss: 1.3451Producer finished: 201200 records produced
#  550/4401 ━━━━━━━━━━━━━━━━━━━━ 8:51 138ms/step - accuracy: 0.6844 - loss: 1.3450
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7400 - loss: 1.0844Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 845s 192ms/step - accuracy: 0.7510 - loss: 1.0352
# Epoch 59/70
# 2417/4401 ━━━━━━━━━━━━━━━━━━━━ 4:40 141ms/step - accuracy: 0.7035 - loss: 1.2736Producer finished: 201200 records produced
# 2421/4401 ━━━━━━━━━━━━━━━━━━━━ 4:40 141ms/step - accuracy: 0.7035 - loss: 1.2735
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7153 - loss: 1.2142Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 847s 192ms/step - accuracy: 0.7381 - loss: 1.1030
# Epoch 60/70
# 4272/4401 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - accuracy: 0.7514 - loss: 1.0346Producer finished: 201200 records produced
# 4276/4401 ━━━━━━━━━━━━━━━━━━━━ 17s 144ms/step - accuracy: 0.7513 - loss: 1.0347
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7508 - loss: 1.0372Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 845s 192ms/step - accuracy: 0.7328 - loss: 1.1217
# Epoch 61/70
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7836 - loss: 0.8736Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 845s 192ms/step - accuracy: 0.7627 - loss: 0.9806
# Epoch 62/70
# 1758/4401 ━━━━━━━━━━━━━━━━━━━━ 6:12 141ms/step - accuracy: 0.7271 - loss: 1.1585Producer finished: 201200 records produced
# 1762/4401 ━━━━━━━━━━━━━━━━━━━━ 6:11 141ms/step - accuracy: 0.7270 - loss: 1.1586
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7416 - loss: 1.0856Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 850s 193ms/step - accuracy: 0.7600 - loss: 0.9945
# Epoch 63/70
# 3645/4401 ━━━━━━━━━━━━━━━━━━━━ 1:48 144ms/step - accuracy: 0.7562 - loss: 1.0070Producer finished: 201200 records produced
# 3649/4401 ━━━━━━━━━━━━━━━━━━━━ 1:48 144ms/step - accuracy: 0.7562 - loss: 1.0071
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7538 - loss: 1.0197Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 846s 192ms/step - accuracy: 0.7474 - loss: 1.0535
# Epoch 64/70
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7787 - loss: 0.8969Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 2026-01-10 03:14:50.689497: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 847s 192ms/step - accuracy: 0.7580 - loss: 1.0051
# Epoch 65/70
# 1131/4401 ━━━━━━━━━━━━━━━━━━━━ 7:36 140ms/step - accuracy: 0.7116 - loss: 1.2294Producer finished: 201200 records produced
# 1135/4401 ━━━━━━━━━━━━━━━━━━━━ 7:35 140ms/step - accuracy: 0.7117 - loss: 1.2290
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7500 - loss: 1.0354Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 843s 192ms/step - accuracy: 0.7702 - loss: 0.9405
# Epoch 66/70
# 3018/4401 ━━━━━━━━━━━━━━━━━━━━ 3:17 143ms/step - accuracy: 0.7492 - loss: 1.0471Producer finished: 201200 records produced
# 3022/4401 ━━━━━━━━━━━━━━━━━━━━ 3:16 143ms/step - accuracy: 0.7492 - loss: 1.0472
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7485 - loss: 1.0501Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 844s 192ms/step - accuracy: 0.7567 - loss: 1.0086
# Epoch 67/70
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7651 - loss: 0.9910Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 846s 192ms/step - accuracy: 0.7554 - loss: 1.0316
# Epoch 68/70
#  504/4401 ━━━━━━━━━━━━━━━━━━━━ 9:03 139ms/step - accuracy: 0.7079 - loss: 1.2151Producer finished: 201200 records produced
#  508/4401 ━━━━━━━━━━━━━━━━━━━━ 9:02 139ms/step - accuracy: 0.7079 - loss: 1.2152
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7605 - loss: 0.9802Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 848s 193ms/step - accuracy: 0.7716 - loss: 0.9374
# Epoch 69/70
# 2391/4401 ━━━━━━━━━━━━━━━━━━━━ 4:47 143ms/step - accuracy: 0.7287 - loss: 1.1507Producer finished: 201200 records produced
# 2395/4401 ━━━━━━━━━━━━━━━━━━━━ 4:46 143ms/step - accuracy: 0.7287 - loss: 1.1507
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7385 - loss: 1.0996Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 851s 193ms/step - accuracy: 0.7580 - loss: 1.0039
# Epoch 70/70
# 4278/4401 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - accuracy: 0.7707 - loss: 0.9524Producer finished: 201200 records produced
# 4282/4401 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - accuracy: 0.7707 - loss: 0.9525
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7701 - loss: 0.9548Producer finished: 201200 records produced
#
# Generator finished: 201200 total records
# 4401/4401 ━━━━━━━━━━━━━━━━━━━━ 853s 194ms/step - accuracy: 0.7522 - loss: 1.0371
#
# Generator finished: 3791 total records
